# %%
import numpy as np 
import pandas as pd

# %%
d = np.load("../data/epochs_subjectsplit.npz", allow_pickle=True)
print(d.keys())
# Out:
# KeysView(NpzFile '../data/epochs_subjectsplit.npz' with keys: X_train, y_train, subject_ids_train, X_val, y_val...)

# %%
data = pd.DataFrame(d)

# %%
print(data.head())
# Out:
#                    0
# 0            X_train
# 1            y_train
# 2  subject_ids_train
# 3              X_val
# 4              y_val

# %%
dp = np.load("../outputs/filtered_resnet/epochs_resnet_subjectsplit_masked.npz", allow_pickle=True)

# %%
dpo = pd.DataFrame(dp)
# Out:
#                    0
# 0            X_train
# 1            y_train
# 2  subject_ids_train
# 3              X_val
# 4              y_val
# 5    subject_ids_val
# 6         keep_ratio
# 7          per_trial
# 8               mode
